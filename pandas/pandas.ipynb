# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))
#index
print(s[0])
print(s[3])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>
# 1
# 4

# %%
s=pd.Series([23,33,43,53], index=["Anna","Sara","Eram","Shifa"])
print(s)
print(s["Anna"])
print(s["Sara"])
# Out:
# Anna     23
# Sara     33
# Eram     43
# Shifa    53
# dtype: int64
# 23
# 33

# %%
s1=pd.Series([1,2,3,4])
s2=pd.Series([10,20,30,40])
print(s1+s2)

s1[0]=100
print(s1)
changed=s1.drop(0)
print(s1)
print(changed)
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# dtype: int64
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
info={
    "Nmae" :["Adam","Bob","Eve"],
    "Age"  :[20,22,23],
    "CGPA" :[8.2,9.4,7.5]
}
df=pd.DataFrame(info)
print(df,type(df))
print(df.index)
print(df.columns)
# Out:
#    Nmae  Age  CGPA
# 0  Adam   20   8.2
# 1   Bob   22   9.4
# 2   Eve   23   7.5 <class 'pandas.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
# Index(['Nmae', 'Age', 'CGPA'], dtype='str')

# %%
df
# Out:
#    Nmae  Age  CGPA
# 0  Adam   20   8.2
# 1   Bob   22   9.4
# 2   Eve   23   7.5

# %%
df=pd.DataFrame([["adam",23],["Bob",34],["Eve",44]],columns=["Name","Age"])

# %%
df
# Out:
#    Name  Age
# 0  adam   23
# 1   Bob   34
# 2   Eve   44

# %%
import numpy as np
np_arr=np.array([["Adam",2,3],["Bob",5,6]])
df=pd.DataFrame(np_arr,columns=["A","B","C"])

# %%
df
# Out:
#       A  B  C
# 0  Adam  2  3
# 1   Bob  5  6

# %%
#csv data
df=pd.read_csv("employee_data.csv")
print(df,type(df))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.DataFrame'>

# %%
#methods
df.head(2) #start 5 data
# Out:
#    ID   Name  Age Department  Salary
# 0   1  Alice   25         HR   55000
# 1   2    Bob   32         IT   72000

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
import pandas as pd
#AQI data set
df=pd.read_csv("globalAirQuality.csv")
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#selecting data
df["city"]
#for rows
df.loc[2]
df.loc[0:2]
df.iloc[2]
df.iloc[0:2]
#for rows nd column
df.loc[0,["city","aqi"]]
df.columns
df.iloc[0,0:3]
#select single vector
df.at[0,"city"]
df.iat[0,2]
# Out:
# 'New York'

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#filtering data
df[df["aqi"]>100]
df[(df["aqi"]>100)&(df["temperature"]>30)]
df[(df["aqi"]>100)&(df["temperature"]>30)][["city","aqi"]]
#diff between lable and index
aqi_data=df[(df["aqi"]>100)&(df["temperature"]>30)][["city","aqi"]]
aqi_data
aqi_data.iloc[0]
#aqi_data.loc[0] # will give error
#query
aqi_val=100
df.query("aqi>100 & temperature>30")[["city","aqi"]]
df.query("aqi>@aqi_val & temperature>30")[["city","aqi"]]
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

# %%
#cleaning data
df=pd.read_csv("raw_data.csv")
df.isnull()
df.isnull().sum(axis=1)#rows
df.isnull().sum()#columns
df.dropna()#columns
df.dropna(axis=1)#rows
df.fillna(0)
df.ffill()
df.bfill()
cleaned_data=df.copy()
age_mean=cleaned_data["age"].mean()
cleaned_data["age"]=cleaned_data["age"].fillna(age_mean)
cleaned_data
# Out:
#     id          name    age country   gender   income
# 0    1      John Doe  29.00     USA     Male  55000.0
# 1    1      John Doe  29.00     USA     Male  55000.0
# 2    2    Jane Smith  32.75  Canada   Female  62000.0
# 3    3          Alex  32.75     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.00   Spain   Female      NaN
# 5    5        Li Wei  27.00   China     Male  51000.0
# 6    6           NaN  45.00   India   Female  73000.0
# 7    7    Ahmed Khan  38.00     NaN     Male  68000.0
# 8    8    Rachel Lee  29.00     USA   Female  62000.0
# 9    9   Carlos Ruiz  32.75  Mexico     Male  45000.0
# 10  10   Emily Davis  31.00     USA      NaN  58000.0

# %%
#handle duplicate val
df.duplicated() #duplicate rows
df[["country","gender"]].duplicated() #columns
#df.drop_duplicates() # removes duplicate rows
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
df.dtypes
df2=df.copy()
df2=df2.fillna(0)
df2["age"]=df2["age"].astype("int64").copy()
df2.dtypes
# Out:
# id           int64
# name        object
# age          int64
# country     object
# gender      object
# income     float64
# dtype: object

# %%
#date time
aqi_data=pd.read_csv("globalAirQuality.csv")
aqi_data
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
date_str=pd.series([pd.to_datetime("2025-11-19")])
tyoe(date_str,dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 date_str=pd.series([pd.to_datetime("2025-11-19")])
#       2 tyoe(date_str,dtype)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
#feature engineering
df2=df.copy()
df2["tax"]=df2["income"].apply(lambda x:"20%"if x>=50000 else "10%")
df2
gender_map={"Male":"M","Female":"F","Unknown":"U"}
df2=df2["gender"].map(gender_map)
df2
df.assign(new_income=df["income"]*1.1)
df["country"]=df["country"].replace("USA","United States")
df
# Out:
#     id          name   age        country   gender   income
# 0    1      John Doe  29.0  United States     Male  55000.0
# 1    1      John Doe  29.0  United States     Male  55000.0
# 2    2    Jane Smith   NaN         Canada   Female  62000.0
# 3    3          Alex   NaN  United States  Unknown  47000.0
# 4    4  Maria Garcia  34.0          Spain   Female      NaN
# 5    5        Li Wei  27.0          China     Male  51000.0
# 6    6           NaN  45.0          India   Female  73000.0
# 7    7    Ahmed Khan  38.0            NaN     Male  68000.0
# 8    8    Rachel Lee  29.0  United States   Female  62000.0
# 9    9   Carlos Ruiz   NaN         Mexico     Male  45000.0
# 10  10   Emily Davis  31.0  United States      NaN  58000.0

# %%
#other methods
df.rename(columns={"income":"salary"})

df_reorderd=df[["name","age","country","gender","income","id"]]
df_reorderd
# Out:
#             name   age        country   gender   income  id
# 0       John Doe  29.0  United States     Male  55000.0   1
# 1       John Doe  29.0  United States     Male  55000.0   1
# 2     Jane Smith   NaN         Canada   Female  62000.0   2
# 3           Alex   NaN  United States  Unknown  47000.0   3
# 4   Maria Garcia  34.0          Spain   Female      NaN   4
# 5         Li Wei  27.0          China     Male  51000.0   5
# 6            NaN  45.0          India   Female  73000.0   6
# 7     Ahmed Khan  38.0            NaN     Male  68000.0   7
# 8     Rachel Lee  29.0  United States   Female  62000.0   8
# 9    Carlos Ruiz   NaN         Mexico     Male  45000.0   9
# 10   Emily Davis  31.0  United States      NaN  58000.0  10

# %%
#sorting
df2=df.copy()
df2.sort_values("income")
df2.sort_values(["age","income"])#sorts age if age same then acc to income
df2_sorted=df2.sort_values(["age","income"])
df2_sorted.sort_index()
# Out:
#     id          name   age        country   gender   income
# 0    1      John Doe  29.0  United States     Male  55000.0
# 1    1      John Doe  29.0  United States     Male  55000.0
# 2    2    Jane Smith   NaN         Canada   Female  62000.0
# 3    3          Alex   NaN  United States  Unknown  47000.0
# 4    4  Maria Garcia  34.0          Spain   Female      NaN
# 5    5        Li Wei  27.0          China     Male  51000.0
# 6    6           NaN  45.0          India   Female  73000.0
# 7    7    Ahmed Khan  38.0            NaN     Male  68000.0
# 8    8    Rachel Lee  29.0  United States   Female  62000.0
# 9    9   Carlos Ruiz   NaN         Mexico     Male  45000.0
# 10  10   Emily Davis  31.0  United States      NaN  58000.0
