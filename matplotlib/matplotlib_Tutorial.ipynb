# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x,y)
plt.show()

# %%
#real data
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008,2009,2010,2011,2012]
oscar_revenue = [1005,170,427,133,232]
#plot
plt.plot(years,oscar_revenue)
plt.title("The Oscar Movie Data")
plt.xlabel("Years which movie won")
plt.ylabel("revenue generated in $M")
# Out:
# Text(0, 0.5, 'revenue generated in $M')

# %%
non_oscarr_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincon"]
non_oscar_revenue = [378,2788,829,185,275]
plt.plot(years,oscar_revenue, "o--r" , label="Oscar Movies")
plt.plot(years,non_oscar_revenue, "<-y" , label="Non-Oscar Movies")
plt.title("The Oscar Movie Revenue vs Non Oscar Movie Revenue ")

plt.xlabel("Years which movie won")
plt.ylabel("revenue generated in $M")
plt.legend(loc="upper right")

# %%
    non_oscarr_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincon"]
    non_oscar_revenue = [378,2788,829,185,275]
    plt.plot(years,oscar_revenue , label="Oscar Movies")
    plt.plot(years,non_oscar_revenue, label="Non-Oscar Movies")
    plt.title("The Oscar Movie Revenue vs Non Oscar Movie Revenue ")

    plt.xlabel("Years which movie won")
    plt.ylabel("revenue generated in $M")
    plt.legend()
    plt.style.available
    plt.style.use("dark_background")
    plt.style.use("ggplot")
    plt.style.use("default")
    # plt.grid()
    plt.show()

# %%
#movie-revenue(tight_layout)
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008,2009,2010,2011,2012]
revenue = [1005,170,427,133,232]
plt.plot(movies,revenue)
plt.tight_layout()
plt.savefig("final_plot.png")

# %%
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008,2009,2010,2011,2012]
revenue = [1005,170,427,133,232]
plt.bar(years,revenue , color="purple")
plt.title("The Oscar Movie Revenue vs Non Oscar Movie Revenue ")

plt.xlabel("Years which movie won")
plt.ylabel("revenue generated in $M")
for i in range(len(years)):
    plt.text(years[i],revenue[i]+5,str(revenue[i]),ha="center")

# %%
import numpy as np
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008,2009,2010,2011,2012]
revenue = [1005,170,427,133,232]
non_oscarr_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincon"]
non_oscar_revenue = [378,2788,829,185,275]

x=np.arange(len(years))
width=0.4

plt.bar(x-width/2,oscar_revenue, width , label="Oscar Movies")
plt.bar(x+width/2,non_oscar_revenue,width, label="Non-Oscar Movies")


plt.title("The Oscar Movie Revenue vs Non Oscar Movie Revenue ")
plt.xlabel("Years")
plt.ylabel("revenue generated in $M")
plt.legend()
plt.xticks(x,years)
# Out:
# ([<matplotlib.axis.XTick at 0x2254e7aa710>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008,2009,2010,2011,2012]
revenue = [1005,170,427,133,232]

plt.barh(movies,revenue)
plt.title("The Oscar Movie Revenue ")
plt.xlabel("Years")
plt.ylabel("revenue generated in $M")
# Out:
# Text(0, 0.5, 'revenue generated in $M')

# %%
# Scatter Plots
people = ["Person A", "Person B", "Person C", "Person D", "Person E", 
          "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
bp = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

colors=["green" if x<135 else "red" for x in bp]
plt.scatter(age, bp, color=colors)
plt.title("Age vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.grid()

plt.scatter(age, bp, color=colors, s=bp, marker='o', alpha=0.5)

# plt.scatter(age, blood_pressure, c=blood_pressure, cmap="plasma")
plt.scatter(age, bp, c=bp, cmap="OrRd")# makes more sense
# plt.scatter(age, blood_pressure, c=[5]*len(age), cmap="plasma")
plt.colorbar(label="BP")

for i in range(len(people)):
    plt.annotate(people[i], xy=(age[i],bp[i]), xytext=(age[i]+1,bp[i]+1))

plt.xlim(min(age),max(age)+10)
plt.ylim(min(bp),max(bp)+10)
# Out:
# (110.0, 160.0)

# %%
# Multiple scatter plots
cities = ["City A", "City B", "City C", "City D", "City E"]


winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]


summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_humidity,winter_temp,label="winter")
plt.scatter(summer_humidity,summer_temp,label="summer")

plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.legend()

# %%
#Pie charts
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]
explode=[0,0,0,0.2,0]
plt.style.use("classic")
plt.pie(amounts, labels=expenses, autopct="%1.1f%%",
        wedgeprops={"edgecolor":"black",
                    "linewidth": 2,
                    "linestyle":"-.", 
                    #"fill":False
        },
        explode=explode,
        startangle=90,
        shadow=True
       )
