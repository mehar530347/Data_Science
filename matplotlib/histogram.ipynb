# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)
scores=np.random.normal(70,10,100)

plt.hist(scores, color="skyblue", edgecolor="black", bins=20)
# Out:
# (array([ 1.,  0.,  1.,  4.,  3.,  4.,  7.,  6.,  7., 10.,  7., 11., 11.,
#          5.,  6.,  5.,  5.,  2.,  3.,  2.]),
#  array([44.47010184, 46.88147406, 49.29284628, 51.7042185 , 54.11559072,
#         56.52696294, 58.93833516, 61.34970738, 63.7610796 , 66.17245182,
#         68.58382404, 70.99519626, 73.40656848, 75.8179407 , 78.22931292,
#         80.64068514, 83.05205736, 85.46342958, 87.8748018 , 90.28617402,
#         92.69754624]),
#  <BarContainer object of 20 artists>)

# %%
marks = [
    25, 38, 42, 55, 61, 67, 72, 78, 83, 88,
    91, 95, 47, 53, 59, 64, 69, 74, 79, 85,
    92, 97, 33, 45, 58, 62, 71, 76, 81, 89
]

# custom bins
bins = [0, 30, 70, 90, 100]
plt.hist(marks, color="skyblue", edgecolor="black", bins=bins)

plt.title("Marks of students")
plt.xlabel("Marks")
plt.ylabel("No. of student")
# Out:
# Text(0, 0.5, 'No. of student')

# %%
marks = [
    25, 38, 42, 55, 61, 67, 72, 78, 83, 88,
    91, 95, 47, 53, 59, 64, 69, 74, 79, 85,
    92, 97, 33, 45, 58, 62, 71, 76, 81, 89
]

# custom bins
bins = [0, 30, 70, 90, 100]
plt.hist(marks, color="skyblue", edgecolor="black", bins=bins)

plt.axvline(
    x=33,
    color="red",
    linestyle="--",
    linewidth=2,
    label="Passing mark is 33",
)

plt.title("Marks of students")
plt.xlabel("Marks")
plt.ylabel("No. of student")
plt.grid(True)

# %%
# Multiple datasets
legit_transactions = [
    2.99, 5.49, 8.99, 12.50, 14.99, 19.99, 23.45, 29.99, 34.99, 39.50,
    45.00, 49.99, 55.25, 60.00, 75.99, 89.99, 120.50, 150.00, 199.99,
    249.99, 300.75, 450.00, 600.00, 850.00, 1200.00
]

fraud_transactions = [
    50, 100, 150, 200, 300, 500, 500, 750, 1000, 1000,
    1200, 1500, 1500, 2000, 2500, 3000, 3000
]

plt.hist(legit_transactions, color="green", bins=10, label="Legit", edgecolor="black", alpha=0.5)
plt.hist(fraud_transactions, color="red", bins=10, label="Legit", edgecolor="black", alpha=0.5)

plt.title("Legit vs Fraud Transaction")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.grid(True)
plt.legend()
