# %%
import matplotlib.pyplot as plt
data=[7,8,5,9,4,10,12,15]
plt.boxplot(data,showmeans=True)
plt.grid(True)

# %%
#multiple data 
import numpy as np
group1 = np.random.normal(50,10,100)
group2 = np.random.normal(60,15,100)

plt.boxplot([group1,group2], tick_labels=["group1","group2"], showmeans=True)
plt.grid(True)
plt.show()

# %%
#horizontal
data=[7,8,5,9,4,10,12,15]
plt.boxplot(data, vert=False)
# Out:
# C:\Users\mehar\AppData\Local\Temp\ipykernel_18112\600902257.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(data, vert=False)
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ddb1bb86e0>,
#   <matplotlib.lines.Line2D at 0x1ddb1bb8830>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ddb1bb8980>,
#   <matplotlib.lines.Line2D at 0x1ddb1bb8ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1ddb1bb8590>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ddb1bb8c20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ddb1bb8d70>],
#  'means': []}
